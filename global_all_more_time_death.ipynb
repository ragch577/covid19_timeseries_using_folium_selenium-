# %%
import numpy as np
import pandas as pd
import folium
import datetime
from folium.plugins import FastMarkerCluster
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from selenium import webdriver
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Tahoma']

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv'
url_death = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv'
url_recovery = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Recovered.csv'
df_con = pd.read_csv(url, error_bad_lines=False)
death = pd.read_csv(url_death, error_bad_lines=False)
recovery = pd.read_csv(url_recovery, error_bad_lines=False)



df_con.drop(df_con.index[[1,2,3]])
death.drop(death.index[[1,2,3]])
recovery.drop(recovery.index[[1,2,3]])


date = df_con.columns[4:]
#print(date)
#print(df_con)


df_confine = df_con.groupby('Country/Region')[date].sum()
#df_total_confine=df.groupby('data')[date].sum()
df_death = death.groupby('Country/Region')[date].sum()
df_recovery = recovery.groupby('Country/Region')[date].sum()



df_confineT = df_death.T

sort_df_confineT = df_confineT.sort_values(by=df_confineT.index[-1],axis=1,ascending=False)

sort_df_confineT_20=sort_df_confineT.iloc[:, : ]
label_sort_df_confineT_20 = sort_df_confineT_20.columns
#value_sort_df_confineT_20 = sort_df_confineT_20.tail(n=1)
value_sort_df_confineT_20 = sort_df_confineT_20

#first_column = value_sort_df_confineT_20.iloc[:, 0]
first_column = value_sort_df_confineT_20.index[:]
print(first_column)
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20',
#        '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20',
#        '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20', '2/15/20',
#        '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20', '2/21/20',
#        '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20',
#        '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20', '3/5/20',
#        '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20', '3/12/20',
#        '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20', '3/18/20',
#        '3/19/20', '3/20/20', '3/21/20', '3/22/20', '3/23/20'],
#       dtype='object')

# %%
df=pd.read_csv('countries.csv', error_bad_lines=False)


data = pd.DataFrame({
   'lat':[-58, 2, 145, 30.32, -4.03, -73.57, 36.82, -38.5],
   'lon':[-34, 49, -38, 59.93, 5.33, 45.52, -1.29, -12.97],
   'name':['Buenos Aires', 'Paris', 'melbourne', 'St Petersbourg', 'Abidjan', 'Montreal', 'Nairobi', 'Salvador'],
   'value':[10,12,40,70,23,43,100,43]
})

from branca.element import Template, MacroElement

template = """
{% macro html(this, kwargs) %}

<!doctype html>
<html lang="en">
<head>
  <meta charset="utf-8">
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <title>jQuery UI Draggable - Default functionality</title>
  <link rel="stylesheet" href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css">

  <script src="https://code.jquery.com/jquery-1.12.4.js"></script>
  <script src="https://code.jquery.com/ui/1.12.1/jquery-ui.js"></script>
  
  <script>
  $( function() {
    $( "#maplegend" ).draggable({
                    start: function (event, ui) {
                        $(this).css({
                            left: "auto",
                            top: "auto",
                            bottom: "auto"
                        });
                    }
                });
});

  </script>
</head>
<body>

 
<div id='maplegend' class='maplegend' 
    style='position: fixed; z-index:9999; border:2px solid grey; background-color:rgba(255, 255, 255, 0.8);
     border-radius:6px; padding: 10px; font-size:14px; left: 10px; bottom: 20px;'>
     
<div class='legend-title'>Legend (draggable!)</div>
<div class='legend-scale'>
  <ul class='legend-labels'>
    <li><span style='background:blue;opacity:0.7;'></span> 0 > and  < 5 cases</li>
    <li><span style='background:red;opacity:0.7;'></span>  5 >= and < 10 cases</li>
    <li><span style='background:green;opacity:0.7;'></span>  10 >= and < 100 cases</li>
    <li><span style='background:olive;opacity:0.7;'></span>  100 >= and < 250 cases</li>
    <li><span style='background:gold;opacity:0.7;'></span>  250 >= and < 500 cases</li>
    <li><span style='background:lime;opacity:0.7;'></span>  500 >= and < 1500 cases</li>
    <li><span style='background:gray;opacity:0.7;'></span>  1500 >= and < 4000 cases</li>
    <li><span style='background:black;opacity:0.7;'></span>  >= 4000 cases</li>
    
    
    

  </ul>
</div>
</div>
 
</body>
</html>

<style type='text/css'>
  .maplegend .legend-title {
    text-align: left;
    margin-bottom: 5px;
    font-weight: bold;
    font-size: 90%;
    }
  .maplegend .legend-scale ul {
    margin: 0;
    margin-bottom: 5px;
    padding: 0;
    float: left;
    list-style: none;
    }
  .maplegend .legend-scale ul li {
    font-size: 80%;
    list-style: none;
    margin-left: 0;
    line-height: 18px;
    margin-bottom: 2px;
    }
  .maplegend ul.legend-labels li span {
    display: block;
    float: left;
    height: 16px;
    width: 30px;
    margin-right: 5px;
    margin-left: 0;
    border: 1px solid #999;
    }
  .maplegend .legend-source {
    font-size: 80%;
    color: #777;
    clear: both;
    }
  .maplegend a {
    color: #777;
    }
</style>
{% endmacro %}"""

macro = MacroElement()
macro._template = Template(template)




print(df)

for iii in range(0,len(date)):
    prod = pd.DataFrame({'latitude': [], 'longitude': [], 'name': [],'radius':[]})
    for i in range(0,len(df)):
        for ii in range(0,len(label_sort_df_confineT_20)):
            if(df.iloc[i]['name']==value_sort_df_confineT_20.columns[ii]):
                #print(df.iloc[i]['latitude'],df.iloc[i]['longitude'],df.iloc[i]['name'],
                #value_sort_df_confineT_20.iloc[iii][value_sort_df_confineT_20.columns[ii]])
                prod = prod.append({'latitude': df.iloc[i]['latitude'], 
                'longitude' : df.iloc[i]['longitude'], 'name' : df.iloc[i]['name'],
                'radius' :value_sort_df_confineT_20.iloc[iii][value_sort_df_confineT_20.columns[ii]]},
                ignore_index=True)

    print(prod)    
    #m = folium.Map(location=[20, 0],tiles='CartoDB dark_matter', zoom_start=1)
    m = folium.Map(location=[20, 0],tiles='cartodbpositron', zoom_start=1.5,title='Hello I am here')
    for k in range(0,len(prod)):
        if(prod.iloc[k]['radius']==0):
            folium.Circle(location=[prod.iloc[k]['latitude'], prod.iloc[k]['longitude']],
            popup=prod.iloc[k]['name'],
            radius=prod.iloc[k]['radius']*8,
            color="#FFFFFF",
            fill=True,
            fill_opacity=0.7,
            line_opacity=0.2,  
            legend_name='Number of confirmed cases'
            ).add_to(m)
        elif(prod.iloc[k]['radius'] > 0 and prod.iloc[k]['radius']<5):
            folium.Circle(location=[prod.iloc[k]['latitude'], prod.iloc[k]['longitude']],
            popup=prod.iloc[k]['name'],
            radius=prod.iloc[k]['radius']*10,
            color="#0000FF",
            fill=True,
            fill_opacity=0.7,
            line_opacity=0.2,  
            legend_name='Number of confirmed cases'
            ).add_to(m)    
        elif(prod.iloc[k]['radius'] >= 5 and prod.iloc[k]['radius']<10):
            folium.Circle(location=[prod.iloc[k]['latitude'], prod.iloc[k]['longitude']],
            popup=prod.iloc[k]['name'],
            radius=prod.iloc[k]['radius']*10,
            color="#FF0000",
            fill=True,
            fill_opacity=0.7,
            line_opacity=0.2,  
            legend_name='Number of confirmed cases'
            ).add_to(m)    
        elif(prod.iloc[k]['radius'] >= 10 and prod.iloc[k]['radius']<100):
            folium.Circle(location=[prod.iloc[k]['latitude'], prod.iloc[k]['longitude']],
            popup=prod.iloc[k]['name'],
            radius=prod.iloc[k]['radius']*10,
            color="#808000",
            fill=True,
            fill_opacity=0.7,
            line_opacity=0.2,  
            legend_name='Number of confirmed cases'
            ).add_to(m)    
        elif(prod.iloc[k]['radius'] >= 100 and prod.iloc[k]['radius']<250):
            folium.Circle(location=[prod.iloc[k]['latitude'], prod.iloc[k]['longitude']],
            popup=prod.iloc[k]['name'],
            radius=prod.iloc[k]['radius']*10,
            color="#808000",
            fill=True,
            fill_opacity=0.7,
            line_opacity=0.2,  
            legend_name='Number of confirmed cases'
            ).add_to(m)        
        elif(prod.iloc[k]['radius'] >= 250 and prod.iloc[k]['radius']<500):
            folium.Circle(location=[prod.iloc[k]['latitude'], prod.iloc[k]['longitude']],
            popup=prod.iloc[k]['name'],
            radius=prod.iloc[k]['radius']*12,
            color="#FFD700",
            fill=True,
            fill_opacity=0.7,
            line_opacity=0.2,  
            legend_name='Number of confirmed cases'
            ).add_to(m)
        elif(prod.iloc[k]['radius'] >= 500 and prod.iloc[k]['radius']<1500):
            folium.Circle(location=[prod.iloc[k]['latitude'], prod.iloc[k]['longitude']],
            popup=prod.iloc[k]['name'],
            radius=prod.iloc[k]['radius']*12,
            color="#00FF00",
            fill=True,
            fill_opacity=0.7,
            line_opacity=0.2,  
            legend_name='Number of confirmed cases'
            ).add_to(m)
        elif(prod.iloc[k]['radius'] >= 1500 and prod.iloc[k]['radius']<4000):
            folium.Circle(location=[prod.iloc[k]['latitude'], prod.iloc[k]['longitude']],
            popup=prod.iloc[k]['name'],
            radius=prod.iloc[k]['radius']*12,
            color="#808080",
            fill=True,
            fill_opacity=0.7,
            line_opacity=0.2,  
            legend_name='Number of confirmed cases'
            ).add_to(m)    
        else:
            folium.Circle(location=[prod.iloc[k]['latitude'], prod.iloc[k]['longitude']],
            popup=prod.iloc[k]['name'],
            radius=prod.iloc[k]['radius']*7,
            color="#000000",
            fill=True,
            fill_opacity=0.7,
            line_opacity=0.2,  
            legend_name='Number of confirmed cases'
            ).add_to(m)
            
    date1=datetime.datetime.strptime(first_column[iii], '%m/%d/%y').strftime('%d-%m-%y')
    title_html = """
             <h3 align="center" style="font-size:20px"><b>Death cases on %s </b></h3>
             """%(date1)
    m.get_root().html.add_child(folium.Element(title_html))
  
        #print(date1)
    m.get_root().add_child(macro)
    tmp=str(iii)+'.html'
    m.save(tmp)
    url='file:///C:/Users/chmtr/Desktop/ML_raghu/Sucess/global_plot_time/'
    driver = webdriver.Chrome(r'C:\Users\chmtr\Downloads\chromedriver_win32\chromedriver.exe')
    driver.get(url+tmp)
    driver.save_screenshot(str(iii)+"death.png")
    driver.close()
# Out:
#     country   latitude  longitude                  name
# 0        AD  42.546245   1.601554               Andorra
# 1        AE  23.424076  53.847818  United Arab Emirates
# 2        AF  33.939110  67.709953           Afghanistan
# 3        AG  17.060816 -61.796428   Antigua and Barbuda
# 4        AI  18.220554 -63.068615              Anguilla
# ..      ...        ...        ...                   ...
# 240      YE  15.552727  48.516388                 Yemen
# 241      YT -12.827500  45.166244               Mayotte
# 242      ZA -30.559482  22.937506          South Africa
# 243      ZM -13.133897  27.849332                Zambia
# 244      ZW -19.015438  29.154857              Zimbabwe
#
# [245 rows x 4 columns]
#       latitude  longitude                  name  radius
# 0    42.546245   1.601554               Andorra     0.0
# 1    23.424076  53.847818  United Arab Emirates     0.0
# 2    33.939110  67.709953           Afghanistan     0.0
# ...
