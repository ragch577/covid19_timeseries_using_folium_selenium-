# %%
import numpy as np
import pandas as pd
import folium
from folium.plugins import FastMarkerCluster
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Tahoma']

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv'
url_death = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv'
url_recovery = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Recovered.csv'
df_con = pd.read_csv(url, error_bad_lines=False)
death = pd.read_csv(url_death, error_bad_lines=False)
recovery = pd.read_csv(url_recovery, error_bad_lines=False)



df_con.drop(df_con.index[[1,2,3]])
death.drop(death.index[[1,2,3]])
recovery.drop(recovery.index[[1,2,3]])


date = df_con.columns[4:]
#print(date)
#print(df_con)


df_confine = df_con.groupby('Country/Region')[date].sum()
#df_total_confine=df.groupby('data')[date].sum()
df_death = death.groupby('Country/Region')[date].sum()
df_recovery = recovery.groupby('Country/Region')[date].sum()



df_confineT = df_confine.T
df_deathT = df_death.T
df_recoveryT = df_recovery.T
#print(df_confineT)

sort_df_confineT = df_confineT.sort_values(by=df_confineT.index[-1],axis=1,ascending=False)
sort_df_recoveryT = df_recoveryT.sort_values(by=df_recoveryT.index[-1],axis=1,ascending=False)
sort_df_deathT = df_deathT.sort_values(by=df_deathT.index[-1],axis=1,ascending=False)


sort_df_confineT_20=sort_df_confineT.iloc[:, : ]
label_sort_df_confineT_20 = sort_df_confineT_20.columns
value_sort_df_confineT_20 = sort_df_confineT_20.tail(n=1)

#first_column = value_sort_df_confineT_20.iloc[:, 0]
first_column = value_sort_df_confineT_20.index[0]
print(first_column)

sort_df_recoveryT_20=sort_df_recoveryT.iloc[:, : 20]
label_sort_df_recoveryT_20 = sort_df_recoveryT_20.columns

sort_df_deathT_20=sort_df_deathT.iloc[:, : 20]
label_sort_df_deathT_20 = sort_df_deathT_20.columns
# Out:
# 3/22/20

# %%
df=pd.read_csv('countries.csv', error_bad_lines=False)

#print(df)

# Make a data frame with dots to show on the map
data = pd.DataFrame({
   'lat':[-58, 2, 145, 30.32, -4.03, -73.57, 36.82, -38.5],
   'lon':[-34, 49, -38, 59.93, 5.33, 45.52, -1.29, -12.97],
   'name':['Buenos Aires', 'Paris', 'melbourne', 'St Petersbourg', 'Abidjan', 'Montreal', 'Nairobi', 'Salvador'],
   'value':[10,12,40,70,23,43,100,43]
})
#print(data)
#prod = []

            
            #print(prod)
            
            
#print(label_sort_df_confineT_20)
#print(prod.columns)
#print(prod)


from branca.element import Template, MacroElement

template = """
{% macro html(this, kwargs) %}

<!doctype html>
<html lang="en">
<head>
  <meta charset="utf-8">
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <title>jQuery UI Draggable - Default functionality</title>
  <link rel="stylesheet" href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css">

  <script src="https://code.jquery.com/jquery-1.12.4.js"></script>
  <script src="https://code.jquery.com/ui/1.12.1/jquery-ui.js"></script>
  
  <script>
  $( function() {
    $( "#maplegend" ).draggable({
                    start: function (event, ui) {
                        $(this).css({
                            right: "auto",
                            top: "auto",
                            bottom: "auto"
                        });
                    }
                });
});

  </script>
</head>
<body>

 
<div id='maplegend' class='maplegend' 
    style='position: absolute; z-index:9999; border:2px solid grey; background-color:rgba(255, 255, 255, 0.8);
     border-radius:6px; padding: 10px; font-size:14px; right: 20px; bottom: 20px;'>
     
<div class='legend-title'>Legend (draggable!)</div>
<div class='legend-scale'>
  <ul class='legend-labels'>
    <li><span style='background:green;opacity:0.7;'></span>< lessthan 100 cases</li>
    <li><span style='background:olive;opacity:0.7;'></span>  100 >= and < 1000 cases</li>
    <li><span style='background:gold;opacity:0.7;'></span>  1000 >= and < 5000 cases</li>
    <li><span style='background:crimson;opacity:0.7;'></span>  5000 >= and < 15000 cases</li>
    <li><span style='background:gray;opacity:0.7;'></span>  15000 >= and < 40000 cases</li>
    <li><span style='background:black;opacity:0.7;'></span>  >= 40000 cases</li>
    
    
    

  </ul>
</div>
</div>
 
</body>
</html>

<style type='text/css'>
  .maplegend .legend-title {
    text-align: left;
    margin-bottom: 5px;
    font-weight: bold;
    font-size: 90%;
    }
  .maplegend .legend-scale ul {
    margin: 0;
    margin-bottom: 5px;
    padding: 0;
    float: left;
    list-style: none;
    }
  .maplegend .legend-scale ul li {
    font-size: 80%;
    list-style: none;
    margin-left: 0;
    line-height: 18px;
    margin-bottom: 2px;
    }
  .maplegend ul.legend-labels li span {
    display: block;
    float: left;
    height: 16px;
    width: 30px;
    margin-right: 5px;
    margin-left: 0;
    border: 1px solid #999;
    }
  .maplegend .legend-source {
    font-size: 80%;
    color: #777;
    clear: both;
    }
  .maplegend a {
    color: #777;
    }
</style>
{% endmacro %}"""

macro = MacroElement()
macro._template = Template(template)


prod = pd.DataFrame({'latitude': [], 'longitude': [], 'name': [],'radius':[]})

print(df)
for i in range(0,len(df)):
    for ii in range(0,len(label_sort_df_confineT_20)):
        if(df.iloc[i]['name']==value_sort_df_confineT_20.columns[ii]):
            print(df.iloc[i]['latitude'],df.iloc[i]['longitude'],df.iloc[i]['name'],value_sort_df_confineT_20.iloc[0][value_sort_df_confineT_20.columns[ii]])
            prod = prod.append({'latitude': df.iloc[i]['latitude'], 'longitude' : df.iloc[i]['longitude'], 'name' : df.iloc[i]['name'],'radius' :value_sort_df_confineT_20.iloc[0][value_sort_df_confineT_20.columns[ii]]},ignore_index=True)

m = folium.Map(location=[20, 0],tiles='CartoDB dark_matter', zoom_start=1)



for i in range(0,len(prod)):
      folium.Circle(location=[prod.iloc[i]['latitude'], prod.iloc[i]['longitude']],
                    popup=prod.iloc[i]['name'],
                    radius=prod.iloc[i]['radius']*8,
                    color='crimson',
                    fill=True,
                    #fill_color='crimson',
                    fill_color='grean',
                    fill_opacity=0.7,
                    line_opacity=0.2,
                    legend_name='Number of cases'
                    ).add_to(m)
        
#m = folium.Map(location=[20, 0],tiles='CartoDB dark_matter', zoom_start=1)
m = folium.Map(location=[20, 0],tiles='cartodbpositron', zoom_start=1)
for i in range(0,len(prod)):
        if(prod.iloc[i]['radius']<100):
             folium.Circle(location=[prod.iloc[i]['latitude'], prod.iloc[i]['longitude']],
                    popup=prod.iloc[i]['name'],
                    radius=prod.iloc[i]['radius']*8,
                    color="#008000",
                    fill=True,
                    fill_opacity=0.7,
                    line_opacity=0.2,  
                    legend_name='Number of confirmed cases'
                    ).add_to(m)
        elif(prod.iloc[i]['radius'] >= 100 and prod.iloc[i]['radius']<1000):
            folium.Circle(location=[prod.iloc[i]['latitude'], prod.iloc[i]['longitude']],
                    popup=prod.iloc[i]['name'],
                    radius=prod.iloc[i]['radius']*10,
                    color="#808000",
                    fill=True,
                    fill_opacity=0.7,
                    line_opacity=0.2,  
                    legend_name='Number of confirmed cases'
                    ).add_to(m)        
        elif(prod.iloc[i]['radius'] >= 1000 and prod.iloc[i]['radius']<5000):
            folium.Circle(location=[prod.iloc[i]['latitude'], prod.iloc[i]['longitude']],
                    popup=prod.iloc[i]['name'],
                    radius=prod.iloc[i]['radius']*12,
                    color="#FFD700",
                    fill=True,
                    fill_opacity=0.7,
                    line_opacity=0.2,  
                    legend_name='Number of confirmed cases'
                    ).add_to(m)
        elif(prod.iloc[i]['radius'] >= 5000 and prod.iloc[i]['radius']<15000):
            folium.Circle(location=[prod.iloc[i]['latitude'], prod.iloc[i]['longitude']],
                    popup=prod.iloc[i]['name'],
                    radius=prod.iloc[i]['radius']*12,
                    color="#DC143C",
                    fill=True,
                    fill_opacity=0.7,
                    line_opacity=0.2,  
                    legend_name='Number of confirmed cases'
                    ).add_to(m)
        elif(prod.iloc[i]['radius'] >= 15000 and prod.iloc[i]['radius']<40000):
            folium.Circle(location=[prod.iloc[i]['latitude'], prod.iloc[i]['longitude']],
                    popup=prod.iloc[i]['name'],
                    radius=prod.iloc[i]['radius']*12,
                    color="#808080",
                    fill=True,
                    fill_opacity=0.7,
                    line_opacity=0.2,  
                    legend_name='Number of confirmed cases'
                    ).add_to(m)    
        else:
            folium.Circle(location=[prod.iloc[i]['latitude'], prod.iloc[i]['longitude']],
                    popup=prod.iloc[i]['name'],
                    radius=prod.iloc[i]['radius']*7,
                    color="#000000",
                    fill=True,
                    fill_opacity=0.7,
                    line_opacity=0.2,  
                    legend_name='Number of confirmed cases'
                    ).add_to(m)
            
       


#3/20/20
import datetime
date=datetime.datetime.strptime(first_column, '%m/%d/%y').strftime('%d-%m-%y')

print(date)
m.get_root().add_child(macro)

m.save(date+'.html')
m
# Out:
#     country   latitude  longitude                  name
# 0        AD  42.546245   1.601554               Andorra
# 1        AE  23.424076  53.847818  United Arab Emirates
# 2        AF  33.939110  67.709953           Afghanistan
# 3        AG  17.060816 -61.796428   Antigua and Barbuda
# 4        AI  18.220554 -63.068615              Anguilla
# ..      ...        ...        ...                   ...
# 240      YE  15.552727  48.516388                 Yemen
# 241      YT -12.827500  45.166244               Mayotte
# 242      ZA -30.559482  22.937506          South Africa
# 243      ZM -13.133897  27.849332                Zambia
# 244      ZW -19.015438  29.154857              Zimbabwe
#
# [245 rows x 4 columns]
# 42.546245 1.6015540000000001 Andorra 113
# 23.424076 53.847818000000004 United Arab Emirates 153
# 33.93911 67.709953 Afghanistan 40
# 17.060816 -61.796428000000006 Antigua and Barbuda 1
# 41.153332 20.168331 Albania 89
# 40.069099 45.038189 Armenia 194
# ...
